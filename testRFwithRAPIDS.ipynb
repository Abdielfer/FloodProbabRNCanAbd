# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split, GridSearchCV 
from sklearn.metrics import accuracy_score
# import some data to play with
iris = datasets.load_iris()
X = iris.data[:, :4]  # we only take the first two features.
y = iris.target
train_data, test_data, train_label, test_label = train_test_split(X, y, test_size=0.2)
param_grid = {
    'n_estimators': np.linspace(1, 220,1).astype(int), #default 100
    'max_depth': [None],  # + list(np.linspace(3, 20).astype(int)),
    'max_features': ['sqrt', None] + list(np.arange(0.5, 1, 0.1)),
    'max_leaf_nodes': [None] + list(np.linspace(10, 50, 500).astype(int)),
    'min_samples_split': [2, 5, 10],
    'bootstrap': [True, False]
    }

# %%
from sklearn.ensemble import RandomForestRegressor as sklRFR 
import multiprocessing as mp
skl_rfr = sklRFR()
cuRFGrid = GridSearchCV(skl_rfr, 
                        param_grid = param_grid,
                        n_jobs = -1, 
                        refit="AUC",
                        cv = 5,
                        verbose = 1, 
                        return_train_score = True
                        )

# %%
# %%time
cuRFGrid.fit(train_data,train_label)
# Out:
# Fitting 5 folds for each of 21042 candidates, totalling 105210 fits
# CPU times: user 23.5 s, sys: 219 ms, total: 23.7 s
# Wall time: 27 s
# GridSearchCV(cv=5, estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'bootstrap': [True, False], 'max_depth': [None],
#                          'max_features': ['sqrt', None, 0.5, 0.6, 0.7,
#                                           0.7999999999999999,
#                                           0.8999999999999999],
#                          'max_leaf_nodes': [None, 10, 10, 10, 10, 10, 10, 10,
#                                             10, 10, 10, 10, 10, 10, 11, 11, 11,
#                                             11, 11, 11, 11, 11, 11, 11, 11, 11,
#                                             12, 12, 12, 12, ...],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': array([1])},
#              refit='AUC', return_train_score=True, verbose=1)

# %%
predicted = cuRFGrid.predict(test_data)
print(predicted,'\n',test_label)
# print(predicted.astype('int'),' \n', test_label)
print('sklearn RF Accuracy Score: ', accuracy_score(predicted.round(), test_label))
# Out:
# [0. 0. 0. 1. 2. 1. 0. 0. 1. 1. 1. 1. 2. 0. 0. 0. 0. 0. 0. 2. 2. 2. 2. 1.
#  2. 1. 0. 1. 1. 0.]
#  [0 0 0 1 2 1 0 0 1 1 1 1 2 0 0 0 0 0 0 2 2 2 2 1 2 1 0 1 1 0]
# sklearn RF Accuracy Score:  1.0
